# %%
import random

print("welcome to Dungeon crawler 0.0001 - tessa help")

#starting health
current_monster_health = 20
current_player_health = 20

#player actions
actions = ["attack", "heal"]

#function determining player dmg
def player_dmg_func():
    return random.randint(1, 4)

#function determining player heal
def player_heal_func():
    return random.randint(2, 5)

#function determining monster dmg
def monster_dmg_func():
    return random.randint(0, 4)

#function asking for input
def player_action(actions):
    choice = input("Actions: attack or heal: ").lower()
    while choice not in actions:
        print("\nPlease, choose attack, or heal.\n")
        choice = input("Actions: attack or heal: ").lower()
    global current_player_health
    global current_monster_health
    if choice == "attack":
        player_attacks_monster(current_monster_health)
    if choice == "heal":
        player_heals(current_player_health)

#function for player healing
def player_heals(value1):
    global current_player_health
    player_heal_func()
    player_heal = player_heal_func()
    value1 += player_heal
    if value1 > 20:
        value1 = 20
        print("You have maximum health!")
    current_player_health = value1
    print("You healed, and have", value1, "health left")
    monster_attacks_player(value1)

#function for player attacks on monster
def player_attacks_monster(value2):
    global current_monster_health
    player_dmg_func()
    player_dmg = player_dmg_func()
    value2 -= player_dmg
    current_monster_health = value2
    print("You attacked the monster with", player_dmg, "attack, it has", value2, "health left")
    if value2 <= 0:
        print("You won!")
    else:
        monster_attacks_player(value2)
    
#function for monster attacks on player
def monster_attacks_player(value3):
    global current_player_health
    monster_dmg_func()
    monster_dmg = monster_dmg_func()
    value3 -= monster_dmg
    current_player_health = value3
    print("The monster attacked you back with", monster_dmg,".", "You have", value3, "health left")
    if current_player_health <= 0:
        print("Game over.")
    else:
        player_action(actions)

player_action(actions)
# Out:
# welcome to Dungeon crawler 0.0001 - tessa help
# Actions: attack or heal: heal
# You have maximum health!
# You healed, and have 20 health left
# The monster attacked you back with 1 . You have 19 health left
# Actions: attack or heal: attack
# You attacked the monster with 4 attack, it has 16 health left
# The monster attacked you back with 0 . You have 16 health left
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-3cf17856cfaf> in <module>
#      74         player_action(actions)
#      75
# ---> 76 player_action(actions)
#
# <ipython-input-8-3cf17856cfaf> in player_action(actions)
#      33         player_attacks_monster(current_monster_health)
#      34     if choice == "heal":
# ---> 35         player_heals(current_player_health)
#      36
#      37 #function for player healing
#
# <ipython-input-8-3cf17856cfaf> in player_heals(value1)
#      46     current_player_health = value1
#      47     print("You healed, and have", value1, "health left")
# ---> 48     monster_attacks_player(value1)
#      49
#      50 #function for player attacks on monster
#
# <ipython-input-8-3cf17856cfaf> in monster_attacks_player(value3)
#      72         print("Game over.")
#      73     else:
# ---> 74         player_action(actions)
#      75
#      76 player_action(actions)
#
# <ipython-input-8-3cf17856cfaf> in player_action(actions)
#      31     global current_monster_health
#      32     if choice == "attack":
# ---> 33         player_attacks_monster(current_monster_health)
#      34     if choice == "heal":
#      35         player_heals(current_player_health)
#
# <ipython-input-8-3cf17856cfaf> in player_attacks_monster(value2)
#      59         print("You won!")
#      60     else:
# ---> 61         monster_attacks_player(value2)
#      62
#      63 #function for monster attacks on player
#
# <ipython-input-8-3cf17856cfaf> in monster_attacks_player(value3)
#      72         print("Game over.")
#      73     else:
# ---> 74         player_action(actions)
#      75
#      76 player_action(actions)
#
# <ipython-input-8-3cf17856cfaf> in player_action(actions)
#      24 #function asking for input
#      25 def player_action(actions):
# ---> 26     choice = input("Actions: attack or heal: ").lower()
#      27     while choice not in actions:
#      28         print("\nPlease, choose attack, or heal.\n")
#
# ~/opt/miniconda3/envs/Boogie_Woogie/lib/python3.8/site-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     858                 "raw_input was called, but this frontend does not support input requests."
#     859             )
# --> 860         return self._input_request(str(prompt),
#     861             self._parent_ident,
#     862             self._parent_header,
#
# ~/opt/miniconda3/envs/Boogie_Woogie/lib/python3.8/site-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     902             except KeyboardInterrupt:
#     903                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 904                 raise KeyboardInterrupt("Interrupted by user") from None
#     905             except Exception as e:
#     906                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
